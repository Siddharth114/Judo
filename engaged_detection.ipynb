# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=data.yaml epochs=25 imgsz=224 plots=True
# Out:
# New https://pypi.org/project/ultralytics/8.0.227 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.226 🚀 Python-3.11.0 torch-2.1.1 CPU (Apple M1)
# engine/trainer: task=detect, mode=train, model=yolov8s.pt, data=data.yaml, epochs=25, patience=50, batch=16, imgsz=224, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train5, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train5
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2116435  ultralytics.nn.modules.head.Detect           [1, [128, 256, 512]]
# Model summary: 225 layers, 11135987 parameters, 11135971 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train5', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# train: Scanning /Users/siddharth/Code/Python/Judo/data/train/labels... 101 image
# train: New cache created: /Users/siddharth/Code/Python/Judo/data/train/labels.cache
# val: Scanning /Users/siddharth/Code/Python/Judo/data/val/labels... 40 images, 0
# val: New cache created: /Users/siddharth/Code/Python/Judo/data/val/labels.cache
# Plotting labels to runs/detect/train5/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 0 dataloader workers
# Logging results to runs/detect/train5
# Starting training for 25 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/25         0G      1.183      1.824      1.312         11        224: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         40         46      0.657      0.804       0.77      0.588
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/25         0G      1.067      1.101      1.202         19        224: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         40         46      0.704      0.804       0.82      0.586
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/25         0G       1.06     0.9711      1.143         14        224: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         40         46      0.612      0.858       0.76       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/25         0G     0.9548     0.8317      1.133         11        224: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         40         46       0.66      0.957       0.92       0.73
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/25         0G     0.9837     0.8332      1.155         17        224: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         40         46      0.763       0.87       0.87      0.674
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/25         0G     0.9297     0.7147      1.142         12        224: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         40         46      0.779       0.87      0.861      0.599
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/25         0G     0.9783     0.7917      1.207         12        224: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         40         46      0.935      0.848      0.863      0.621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/25         0G     0.9248     0.7032      1.123         20        224: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         40         46      0.806      0.826      0.827       0.56
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/25         0G     0.9288     0.7438      1.107         18        224: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         40         46      0.738      0.587      0.706      0.482
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/25         0G     0.9726     0.7268      1.155         10        224: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         40         46       0.79      0.804      0.827      0.569
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/25         0G     0.9048     0.6225      1.123         15        224: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         40         46      0.727      0.804      0.835      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/25         0G      0.934     0.6703      1.146         16        224: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         40         46      0.807      0.911      0.903      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/25         0G     0.9239     0.6939      1.126         27        224: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         40         46      0.747      0.804      0.797      0.511
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/25         0G     0.9465     0.6911      1.171         13        224: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         40         46      0.695      0.913       0.83      0.498
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/25         0G     0.9949     0.7598       1.17         11        224: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         40         46      0.832      0.891      0.905      0.617
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/25         0G     0.8094     0.8037      1.129          6        224: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         40         46      0.791       0.87      0.884      0.587
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/25         0G     0.7896     0.7104       1.07          9        224: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         40         46      0.807      0.826      0.874      0.594
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/25         0G     0.7737     0.7003       1.06          7        224: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         40         46      0.747      0.834      0.833      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/25         0G     0.7647     0.6149      1.016          6        224: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         40         46      0.793      0.917      0.895      0.634
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/25         0G     0.7158     0.5943      1.051          6        224: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         40         46      0.947       0.87      0.923      0.666
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/25         0G     0.7373     0.5683      1.066          7        224: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         40         46       0.95      0.831      0.913      0.672
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/25         0G     0.6929     0.5289      1.052          5        224: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         40         46       0.89      0.848      0.915      0.657
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/25         0G     0.7168     0.5493       1.01         10        224: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         40         46      0.879      0.793      0.878      0.645
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/25         0G     0.6448     0.4777      1.004          5        224: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         40         46      0.867      0.913      0.913      0.663
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/25         0G     0.6242     0.4742     0.9714          6        224: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         40         46      0.951      0.837      0.917      0.685
#
# 25 epochs completed in 0.134 hours.
# Optimizer stripped from runs/detect/train5/weights/last.pt, 22.5MB
# Optimizer stripped from runs/detect/train5/weights/best.pt, 22.5MB
#
# Validating runs/detect/train5/weights/best.pt...
# Ultralytics YOLOv8.0.226 🚀 Python-3.11.0 torch-2.1.1 CPU (Apple M1)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         40         46      0.662      0.957      0.919      0.728
# Speed: 0.2ms preprocess, 61.6ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to runs/detect/train5
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
# !ls runs/detect/train/
# Out:
# F1_curve.png
# PR_curve.png
# P_curve.png
# R_curve.png
# args.yaml
# confusion_matrix.png
# confusion_matrix_normalized.png
# events.out.tfevents.1702439081.Siddharths-MacBook-Pro.local.26861.0
# labels.jpg
# labels_correlogram.jpg
# results.csv
# results.png
# train_batch0.jpg
# train_batch1.jpg
# train_batch105.jpg
# train_batch106.jpg
# train_batch107.jpg
# train_batch2.jpg
# val_batch0_labels.jpg
# val_batch0_pred.jpg
# val_batch1_labels.jpg
# val_batch1_pred.jpg
# weights

# %%
Image(filename='runs/detect/train/confusion_matrix.png', width=600)

# %%
Image(filename='runs/detect/train/results.png', width=600)

# %%
Image(filename='runs/detect/train/val_batch0_pred.jpg', width=600)

# %%
# !yolo task=detect mode=val model=runs/detect/train/weights/best.pt data=data.yaml
# Out:
# Ultralytics YOLOv8.0.226 🚀 Python-3.11.0 torch-2.1.1 CPU (Apple M1)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /Users/siddharth/Code/Python/Judo/data/val/labels.cache... 40 imag
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         40         46      0.662      0.957      0.919      0.728
# Speed: 0.2ms preprocess, 76.8ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt source=data/test/images conf=0.95
# Out:
# Ultralytics YOLOv8.0.226 🚀 Python-3.11.0 torch-2.1.1 CPU (Apple M1)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/10 /Users/siddharth/Code/Python/Judo/data/test/images/1.png: 224x224 4 engageds, 36.5ms
# image 2/10 /Users/siddharth/Code/Python/Judo/data/test/images/10.jpg: 128x224 1 engaged, 21.9ms
# image 3/10 /Users/siddharth/Code/Python/Judo/data/test/images/2.jpeg: 224x224 1 engaged, 32.0ms
# image 4/10 /Users/siddharth/Code/Python/Judo/data/test/images/3.jpg: 224x192 1 engaged, 29.4ms
# image 5/10 /Users/siddharth/Code/Python/Judo/data/test/images/4.jpg: 160x224 6 engageds, 25.8ms
# image 6/10 /Users/siddharth/Code/Python/Judo/data/test/images/5.jpg: 192x224 1 engaged, 29.9ms
# image 7/10 /Users/siddharth/Code/Python/Judo/data/test/images/6.jpg: 192x224 2 engageds, 30.6ms
# image 8/10 /Users/siddharth/Code/Python/Judo/data/test/images/7.jpeg: 160x224 1 engaged, 25.4ms
# image 9/10 /Users/siddharth/Code/Python/Judo/data/test/images/8.jpeg: 128x224 1 engaged, 24.0ms
# image 10/10 /Users/siddharth/Code/Python/Judo/data/test/images/9.jpeg: 160x224 1 engaged, 26.4ms
# Speed: 0.6ms preprocess, 28.2ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
